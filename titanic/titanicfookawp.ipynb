# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load



# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"

# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
file_train_data = "data/train.csv"
file_test_data = "data/test.csv"

# %%
import csv


train_csv = []
with open(file_train_data, "r") as f:
    reader = csv.DictReader(f)

    for row in reader:
        train_csv.append(row)

print(train_csv[:3])

test_csv = []
with open(file_test_data, "r") as f:
    reader = csv.DictReader(f)

    for row in reader:
        test_csv.append(row)

print(test_csv[:3])
# Out:
# [{'PassengerId': '1', 'Survived': '0', 'Pclass': '3', 'Name': 'Braund, Mr. Owen Harris', 'Sex': 'male', 'Age': '22', 'SibSp': '1', 'Parch': '0', 'Ticket': 'A/5 21171', 'Fare': '7.25', 'Cabin': '', 'Embarked': 'S'}, {'PassengerId': '2', 'Survived': '1', 'Pclass': '1', 'Name': 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'Sex': 'female', 'Age': '38', 'SibSp': '1', 'Parch': '0', 'Ticket': 'PC 17599', 'Fare': '71.2833', 'Cabin': 'C85', 'Embarked': 'C'}, {'PassengerId': '3', 'Survived': '1', 'Pclass': '3', 'Name': 'Heikkinen, Miss. Laina', 'Sex': 'female', 'Age': '26', 'SibSp': '0', 'Parch': '0', 'Ticket': 'STON/O2. 3101282', 'Fare': '7.925', 'Cabin': '', 'Embarked': 'S'}]
# [{'PassengerId': '892', 'Pclass': '3', 'Name': 'Kelly, Mr. James', 'Sex': 'male', 'Age': '34.5', 'SibSp': '0', 'Parch': '0', 'Ticket': '330911', 'Fare': '7.8292', 'Cabin': '', 'Embarked': 'Q'}, {'PassengerId': '893', 'Pclass': '3', 'Name': 'Wilkes, Mrs. James (Ellen Needs)', 'Sex': 'female', 'Age': '47', 'SibSp': '1', 'Parch': '0', 'Ticket': '363272', 'Fare': '7', 'Cabin': '', 'Embarked': 'S'}, {'PassengerId': '894', 'Pclass': '2', 'Name': 'Myles, Mr. Thomas Francis', 'Sex': 'male', 'Age': '62', 'SibSp': '0', 'Parch': '0', 'Ticket': '240276', 'Fare': '9.6875', 'Cabin': '', 'Embarked': 'Q'}]

# %%
import copy

special_titles = ["Dr", "Rev", "Col", "Major", "Sir", "Lady"]

def parse_data(lines):
    # First we filter out the data we need
    data = []
    for l in lines:
        data.append(
            {
                "id": l["PassengerId"],
                "survived": l.get("Survived", 0),
                "class": l["Pclass"],
                "sex": l["Sex"],
                "age": l["Age"],
                "sibsp": l["SibSp"],
                "parch": l["Parch"],
                "fare": l.get("Fare", 0),
                # "embarked": l["Embarked"], # Seems irrelevant
                "has_cabin": 0 if l["Cabin"] == "" else 1,
                "has_title": 1 if any(title in l["Name"] for title in special_titles) else 0,
            }
        )

    # Normalize data
    norm_sex = {"male": 0, "female": 1}
    norm_embarked = {"S": 0, "C": 1, "Q": 2, "": 3}

    normalized_data = []
    # Numberize values
    for row in data:
        # Check for errors
        if norm_sex.get(row["sex"], "unknown") == "unknown":
            print(row["id"], row["sex"])
        # if norm_embarked.get(row["embarked"], "unknown") == "unknown":
        #     print(row["id"], row["embarked"])

        nd = copy.deepcopy(row)

        nd["sex"] = norm_sex[row["sex"]]
        nd["fare"] = float(row["fare"]) if row["fare"] != "" else 0
        # nd["embarked"] = norm_embarked[row["embarked"]]
        nd["age"] = float(row["age"]) if row["age"] != "" else 0

        normalized_data.append(nd)

    # Add median age if age is 0
    ages = [d["age"] for d in normalized_data if d["age"] != 0]
    median_age = sorted(ages)[len(ages) // 2]
    for r in normalized_data:
        if r["age"] == 0:
            r["age"] = median_age


    keys = list(normalized_data[0].keys())

    # Extract min max of each key
    keys_minmax = {}
    for k in keys:
        values = [d[k] for d in normalized_data if k in d]
        # print(values)
        min_value, max_value = float(min(values)), float(max(values))
        keys_minmax[k] = {"min": min_value, "max": max_value}

    # Normalize 0 to 1 all keys
    for r in normalized_data:
        for k in keys:
            if k == "id":
                continue
            value = float(r[k])
            minmax = keys_minmax[k]
            norm_value = (value - minmax["min"]) / (minmax["max"] - minmax["min"]) if (minmax["max"] - minmax["min"]) != 0 else 0.0
            r[k] = norm_value
            # print(keys_minmax[k], value, norm_value)

    # Split data into input -> expected output
    train_data = []
    for r in normalized_data:
        train_data.append(
            {
                "id": r["id"],
                "input": list(
                    {k: v for k, v in r.items() if k not in ["survived", "id"]}.values()
                ),
                "output": [r["survived"]],
            }
        )

    return train_data

train_data = parse_data(train_csv)
print(train_data[:3])

test_data = parse_data(test_csv)
print(test_data[:3])
# Out:
# [{'id': '1', 'input': [1.0, 0.0, 0.2711736617240513, 0.125, 0.0, 0.014151057562208049, 0.0, 0.0], 'output': [0.0]}, {'id': '2', 'input': [0.0, 1.0, 0.4722292033174164, 0.125, 0.0, 0.13913573538264068, 1.0, 0.0], 'output': [1.0]}, {'id': '3', 'input': [1.0, 1.0, 0.32143754712239253, 0.0, 0.0, 0.015468569817999833, 0.0, 0.0], 'output': [1.0]}]
# [{'id': '892', 'input': [1.0, 0.0, 0.45272319662402744, 0.0, 0.0, 0.015281580671177828, 0.0, 0.0], 'output': [0.0]}, {'id': '893', 'input': [1.0, 1.0, 0.6175656072794409, 0.125, 0.0, 0.013663090060062943, 0.0, 0.0], 'output': [0.0]}, {'id': '894', 'input': [0.5, 0.0, 0.815376500065937, 0.0, 0.0, 0.018908740708122825, 0.0, 0.0], 'output': [0.0]}]

# %%
import torch.nn as nn
import torch
import numpy as np
from typing import List

# Determine the best available device
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    elif torch.backends.mps.is_available():
        return torch.device("mps")
    else:
        return torch.device("cpu")


# DEVICE = torch.device("cpu")
DEVICE = get_device()
print(DEVICE)

class SimpleNeuralNetwork(nn.Module):
    """Simple feedforward neural network using PyTorch"""

    def __init__(
        self,
        input_size: int = 16,
        hidden_layers: List[int] = [256],
        output_size: int = 4,
        empty: bool = False,
    ):
        super().__init__()

        if empty:
            return

        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.output_size = output_size

        # Build layers using PyTorch modules
        layers = []
        prev_size = input_size

        # Add hidden layers
        for hidden_size in hidden_layers:
            layers.append(nn.Linear(prev_size, hidden_size))
            layers.append(nn.ReLU())
            # layers.append(nn.Sigmoid())
            prev_size = hidden_size

        # Add output layer (no activation)
        layers.append(nn.Linear(prev_size, output_size))

        self.network = nn.Sequential(*layers)

        # Initialize weights using He initialization
        self._initialize_weights()

        # Move to device
        self.to(DEVICE)

    def _initialize_weights(self):
        """Initialize weights using He initialization"""
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight, nonlinearity="tanh")
                nn.init.zeros_(module.bias)

    def forward(self, x):
        """Forward pass through the network"""
        # Convert numpy array to tensor if needed and move to device
        if isinstance(x, np.ndarray):
            x = torch.from_numpy(x).float().to(DEVICE)
        elif isinstance(x, torch.Tensor):
            x = x.to(DEVICE)
        elif isinstance(x, list):
            x = torch.tensor(x, dtype=torch.float32).to(DEVICE)

        return self.network(x)

    def mutate(self, mutation_rate: float = 0.1, mutation_strength: float = 0.5):
        """Mutate the network's weights and biases"""
        with torch.no_grad():
            for param in self.parameters():
                if torch.rand(1).item() < mutation_rate:
                    mutation = torch.randn_like(param) * mutation_strength
                    param.add_(mutation)
# Out:
# cuda

# %%
from joblib import Parallel, delayed
import joblib
from typing import List
from typing import Tuple
import numpy as np
import random


class EvolutionaryOptimizer:
    def __init__(
        self,
        population_size: int = 50,
        elite_size: int = 10,
        new_members: int = 0,
        mutation_rate: float = 0.1,
        mutation_strength: float = 0.5,
        input_size: int = 8,
        hidden_layers: List[int] = [32],
        output_size: int = 1,
        train_data: List = [],
        train_size: int = 0,
    ):
        self.population_size = population_size
        self.elite_size = elite_size
        self.new_members = new_members
        self.mutation_rate = mutation_rate
        self.mutation_strength = mutation_strength
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_layers = hidden_layers
        self.train_data = train_data
        self.train_size = train_size if train_size > 0 else len(train_data)

        # Convert training data to tensors once
        self.input_tensor = torch.tensor([data['input'] for data in train_data], dtype=torch.float32).to(DEVICE)
        self.output_tensor = torch.tensor([data['output'] for data in train_data], dtype=torch.float32).to(DEVICE)

        # Create initial population
        self.population = []
        for _ in range(population_size):
            network = SimpleNeuralNetwork(
                input_size=input_size,
                output_size=output_size,
                hidden_layers=hidden_layers,
            )
            self.population.append(network)

    def evaluate(
        self,
    ) -> List[Tuple[SimpleNeuralNetwork, int, float]]:
        if DEVICE.type == "cuda" or DEVICE.type == "mps":
            # GPU evaluation - process all networks sequentially since GPU handles parallelization
            results = []
            for network in self.population:
                network.eval()
                with torch.no_grad():
                    predictions = network(self.input_tensor)
                    predictions = (predictions > 0.5).float()
                    accuracy = (predictions == self.output_tensor).float().mean().item()
                    results.append((network, accuracy))
            return results
        else:
            # CPU evaluation - use joblib for parallel processing
            def eval_network(network: SimpleNeuralNetwork):
                network.eval()
                scores = []
                with torch.no_grad():
                    for test in self.train_data:
                        input_values = test['input']
                        prediction = network.forward(input_values)
                        prediction = True if prediction[0] > .5 else False
                        reality = True if test['output'][0] == 1.0 else False
                        scores.append(1 if prediction == reality else 0)
                return (network, sum(scores) / len(scores))

            results = Parallel(n_jobs=joblib.cpu_count())(
                delayed(eval_network)(net) for net in self.population
            )
            return results

    def select_and_breed(
        self, evaluated: List[Tuple[SimpleNeuralNetwork, int, float]]
    ) -> None:
        # Sort by score descending
        evaluated.sort(key=lambda x: x[1], reverse=True)
        elite = evaluated[: self.elite_size]

        new_population = []
        # Keep elite networks
        for net, _ in elite:
            new_population.append(net)

        # Create offspring by mutating elite networks
        while len(new_population) < self.population_size:
            parent = random.choice(elite)[0]

            # Create a child by copying the parent's state
            child = copy.deepcopy(parent)

            # Mutate the child
            child.mutate(self.mutation_rate, self.mutation_strength)
            new_population.append(child)

        # Add random new members
        for _ in range(self.new_members):
            network = SimpleNeuralNetwork(hidden_layers=self.hidden_layers, input_size=self.input_size, output_size=self.output_size)
            new_population.append(network)

        self.population = new_population

    def run_generation(
        self,
    ) -> Tuple[List[SimpleNeuralNetwork], float]:
        evaluated = self.evaluate()
        best_precision = max(precision for _, precision in evaluated)

        self.select_and_breed(evaluated)

        return self.population, best_precision

# %%
import pickle

def save_network(network: SimpleNeuralNetwork, filename: str):
    torch.save(network.state_dict(), filename)


def load_network(filename: str, hidden_layers: List[int]) -> SimpleNeuralNetwork:
    network = SimpleNeuralNetwork(hidden_layers=hidden_layers)
    network.load_state_dict(torch.load(filename, map_location=DEVICE))
    network.to(DEVICE)
    return network


def save_population(population: List[SimpleNeuralNetwork], filename: str):
    with open(filename, "wb") as f:
        pickle.dump(population, f)


def load_population(filename: str) -> List[SimpleNeuralNetwork]:
    with open(filename, "rb") as f:
        population = pickle.load(f)
    return population

# %%
import time
from datetime import timedelta

generations = 1000
hidden_layers = [16, 8, 4, 2]
mutation_rate = 0.25
mutation_strength = 0.25

folder = f"networks/{'_'.join(str(x) for x in hidden_layers)}"
os.makedirs(folder, exist_ok=True)
print(f"Saving networks to folder: {folder}")

scores_best = []

def mutation_decay(x, mu0=0.25, k=3.0):
    return mu0 * np.exp(-k * x)

start_time = time.time()

epoch = 0
last_precision = 0
while True:
    print(f"Epoch {epoch+1} starting...")
    epoch += 1

    optimizer = EvolutionaryOptimizer(
        population_size=100,
        elite_size=10,
        new_members=0,
        mutation_rate=mutation_rate,
        mutation_strength=mutation_strength,
        input_size=len(train_data[0]['input']),
        hidden_layers=hidden_layers,
        output_size=1,
        train_data=random.sample(train_data, len(train_data) // 4),
    )

    for gen in range(generations):
        optimizer.mutation_strength = mutation_decay(
            gen / generations, k=8, mu0=mutation_strength
        )
        optimizer.mutation_rate = mutation_decay(gen / generations, k=8, mu0=mutation_rate)

        (population, best_precision) = optimizer.run_generation()
        # print(f"Epoch: {epoch} {gen+1}/{generations} - Best Precision: {best_precision:.4f}")

    elapsed_time = time.time() - start_time
    duration = str(timedelta(seconds=(elapsed_time)))
    print(f"Epoch {epoch} completed after {duration}")
    if best_precision > last_precision:
        save_population(optimizer.population, f"{folder}/population_epoch_{epoch}.pkl")
        last_precision = best_precision    
        print(f"Saved population for epoch {epoch} with precision {best_precision:.4f}")
# Out:
# Saving networks to folder: networks/16_8_4_2
# Epoch 1 starting...
# Epoch 1 completed after 0:01:24.048354
# Saved population for epoch 1 with precision 0.8649
# Epoch 2 starting...
# Epoch 2 completed after 0:02:47.778349
# Epoch 3 starting...
# Epoch 3 completed after 0:04:12.279450
# Saved population for epoch 3 with precision 0.8739
# Epoch 4 starting...
# Epoch 4 completed after 0:05:38.354220
# Epoch 5 starting...
# Epoch 5 completed after 0:07:03.132288
# Saved population for epoch 5 with precision 0.8784
# Epoch 6 starting...
# Epoch 6 completed after 0:08:26.971521
# Epoch 7 starting...
# Epoch 7 completed after 0:09:51.716761
# Epoch 8 starting...
# Epoch 8 completed after 0:11:16.422262
# Epoch 9 starting...
# Epoch 9 completed after 0:12:42.227675
# Epoch 10 starting...
# Epoch 10 completed after 0:14:06.872485
# Epoch 11 starting...
# Epoch 11 completed after 0:15:31.901779
# Epoch 12 starting...
# Epoch 12 completed after 0:16:57.109278
# Epoch 13 starting...
# Epoch 13 completed after 0:18:24.556825
# Epoch 14 starting...
# Epoch 14 completed after 0:19:50.372581
# Epoch 15 starting...
# Epoch 15 completed after 0:21:14.275586
# Epoch 16 starting...
# Epoch 16 completed after 0:22:38.368263
# Epoch 17 starting...
# Epoch 17 completed after 0:24:02.336251
# Epoch 18 starting...
# Epoch 18 completed after 0:25:26.035180
# Epoch 19 starting...
# Epoch 19 completed after 0:26:50.701007
# Epoch 20 starting...
# Epoch 20 completed after 0:28:16.910897
# Epoch 21 starting...
# Epoch 21 completed after 0:29:43.150051
# Saved population for epoch 21 with precision 0.8829
# Epoch 22 starting...
# Epoch 22 completed after 0:31:10.692970
# Epoch 23 starting...
# Epoch 23 completed after 0:32:36.812244
# Epoch 24 starting...
# Epoch 24 completed after 0:34:02.371079
# Epoch 25 starting...
# Epoch 25 completed after 0:35:27.102850
# Epoch 26 starting...
# Epoch 26 completed after 0:36:51.950803
# Epoch 27 starting...
# Epoch 27 completed after 0:38:15.985720
# Epoch 28 starting...
# Epoch 28 completed after 0:39:41.259805
# Epoch 29 starting...
# Epoch 29 completed after 0:41:08.008208
# Epoch 30 starting...
# Epoch 30 completed after 0:42:35.037235
# Epoch 31 starting...
# Epoch 31 completed after 0:44:02.853515
# Epoch 32 starting...
# Epoch 32 completed after 0:45:30.856745
# Epoch 33 starting...
# Epoch 33 completed after 0:46:55.383107
# Epoch 34 starting...
# Epoch 34 completed after 0:48:21.212697
# Epoch 35 starting...
# Epoch 35 completed after 0:49:48.923160
# Epoch 36 starting...
# Epoch 36 completed after 0:51:16.888779
# Epoch 37 starting...
# Epoch 37 completed after 0:52:42.955948
# Epoch 38 starting...
# Epoch 38 completed after 0:54:06.891668
# Epoch 39 starting...
# Epoch 39 completed after 0:55:30.341661
# Epoch 40 starting...
# Epoch 40 completed after 0:56:54.039232
# Saved population for epoch 40 with precision 0.9009
# Epoch 41 starting...
# Epoch 41 completed after 0:58:17.896553
# Epoch 42 starting...
# Epoch 42 completed after 0:59:42.003888
# Epoch 43 starting...
# Epoch 43 completed after 1:01:08.331336
# Epoch 44 starting...
# Epoch 44 completed after 1:02:36.225485
# Epoch 45 starting...
# Epoch 45 completed after 1:04:04.276441
# Epoch 46 starting...
# Epoch 46 completed after 1:05:31.408050
# Epoch 47 starting...
# Epoch 47 completed after 1:06:55.934737
# Epoch 48 starting...
# Epoch 48 completed after 1:08:20.208455
# Epoch 49 starting...
# Epoch 49 completed after 1:09:43.511499
# Epoch 50 starting...
# Epoch 50 completed after 1:11:06.921780
# Epoch 51 starting...
# Epoch 51 completed after 1:12:31.683025
# Epoch 52 starting...
# Epoch 52 completed after 1:13:55.813758
# Epoch 53 starting...
# Epoch 53 completed after 1:15:18.963847
# Epoch 54 starting...
# Epoch 54 completed after 1:16:42.050908
# Epoch 55 starting...
# Epoch 55 completed after 1:18:05.479024
# Epoch 56 starting...
# Epoch 56 completed after 1:19:28.960603
# Epoch 57 starting...
# Epoch 57 completed after 1:20:52.200630
# Epoch 58 starting...
# Epoch 58 completed after 1:22:15.539463
# Epoch 59 starting...
# Epoch 59 completed after 1:23:38.896731
# Epoch 60 starting...
# Epoch 60 completed after 1:25:02.697286
# Epoch 61 starting...
# Epoch 61 completed after 1:26:26.242808
# Epoch 62 starting...
# Epoch 62 completed after 1:27:49.435856
# Epoch 63 starting...
# Epoch 63 completed after 1:29:14.022547
# Epoch 64 starting...
# Epoch 64 completed after 1:30:38.519874
# Epoch 65 starting...
# Epoch 65 completed after 1:32:03.533884
# Epoch 66 starting...
# Epoch 66 completed after 1:33:28.589458
# Epoch 67 starting...
# Epoch 67 completed after 1:34:52.105441
# Epoch 68 starting...
# Epoch 68 completed after 1:36:15.307194
# Epoch 69 starting...
# Epoch 69 completed after 1:37:38.579826
# Epoch 70 starting...
# Epoch 70 completed after 1:39:02.710536
# Epoch 71 starting...
# Epoch 71 completed after 1:40:26.295256
# Epoch 72 starting...
# Epoch 72 completed after 1:41:50.362805
# Epoch 73 starting...
# Epoch 73 completed after 1:43:15.480016
# Epoch 74 starting...
# Epoch 74 completed after 1:44:38.839625
# Epoch 75 starting...
# Epoch 75 completed after 1:46:03.658803
# Epoch 76 starting...
# Epoch 76 completed after 1:47:26.791823
# Epoch 77 starting...
# Epoch 77 completed after 1:48:50.942626
# Epoch 78 starting...
# Epoch 78 completed after 1:50:17.711302
# Epoch 79 starting...
# Epoch 79 completed after 1:51:42.434953
# Epoch 80 starting...
# Epoch 80 completed after 1:53:07.354271
# Epoch 81 starting...
# Epoch 81 completed after 1:54:31.141648
# Epoch 82 starting...
# Epoch 82 completed after 1:55:54.960000
# Epoch 83 starting...
# Epoch 83 completed after 1:57:19.613474
# Epoch 84 starting...
# Epoch 84 completed after 1:58:43.872670
# Epoch 85 starting...
# Epoch 85 completed after 2:00:08.472885
# Epoch 86 starting...
# Epoch 86 completed after 2:01:31.919272
# Epoch 87 starting...
# Epoch 87 completed after 2:02:56.597581
# Epoch 88 starting...
# Epoch 88 completed after 2:04:21.135887
# Epoch 89 starting...
# Epoch 89 completed after 2:05:45.214083
# Epoch 90 starting...
# Epoch 90 completed after 2:07:08.849674
# Epoch 91 starting...
# Epoch 91 completed after 2:08:33.316770
# Epoch 92 starting...
# Epoch 92 completed after 2:09:58.985287
# Epoch 93 starting...
# Epoch 93 completed after 2:11:23.297327
# Epoch 94 starting...
# Epoch 94 completed after 2:12:46.944570
# Epoch 95 starting...
# Epoch 95 completed after 2:14:10.263841
# Epoch 96 starting...
# Epoch 96 completed after 2:15:33.502175
# Epoch 97 starting...
# Epoch 97 completed after 2:16:57.075154
# Epoch 98 starting...
# Epoch 98 completed after 2:18:20.486297
# Epoch 99 starting...
# Epoch 99 completed after 2:19:45.178936
# Epoch 100 starting...
# Epoch 100 completed after 2:21:09.130356
# Epoch 101 starting...
# Epoch 101 completed after 2:22:32.570485
# Epoch 102 starting...
# Epoch 102 completed after 2:23:55.890636
# Epoch 103 starting...
# Epoch 103 completed after 2:25:19.311427
# Epoch 104 starting...
# Epoch 104 completed after 2:26:44.497509
# Epoch 105 starting...
# Epoch 105 completed after 2:28:10.768604
# Epoch 106 starting...
# Epoch 106 completed after 2:29:35.986082
# Epoch 107 starting...
# Epoch 107 completed after 2:31:00.003022
# Epoch 108 starting...
# Epoch 108 completed after 2:32:25.528761
# Epoch 109 starting...
# Epoch 109 completed after 2:33:52.047633
# Epoch 110 starting...
# Epoch 110 completed after 2:35:17.507936
# Epoch 111 starting...
# Epoch 111 completed after 2:36:41.824821
# Epoch 112 starting...
# Epoch 112 completed after 2:38:06.753791
# Epoch 113 starting...
# Epoch 113 completed after 2:39:30.947392
# Epoch 114 starting...
# Epoch 114 completed after 2:40:54.581264
# Epoch 115 starting...
# Epoch 115 completed after 2:42:20.178798
# Epoch 116 starting...
# Epoch 116 completed after 2:43:45.398719
# Epoch 117 starting...
# Epoch 117 completed after 2:45:10.239429
# Epoch 118 starting...
# Epoch 118 completed after 2:46:33.887125
# Epoch 119 starting...
# Epoch 119 completed after 2:47:57.773220
# Epoch 120 starting...
# Epoch 120 completed after 2:49:21.613080
# Epoch 121 starting...
# Epoch 121 completed after 2:50:45.964082
# Epoch 122 starting...
# Epoch 122 completed after 2:52:09.864769
# Epoch 123 starting...
# Epoch 123 completed after 2:53:32.821818
# Epoch 124 starting...
# Epoch 124 completed after 2:54:56.965120
# Epoch 125 starting...
# Epoch 125 completed after 2:56:23.603695
# Epoch 126 starting...
# Epoch 126 completed after 2:57:47.360108
# Epoch 127 starting...
# Epoch 127 completed after 2:59:10.689511
# Epoch 128 starting...
# Epoch 128 completed after 3:00:34.201365
# Epoch 129 starting...
# Epoch 129 completed after 3:01:57.861292
# Epoch 130 starting...
# Epoch 130 completed after 3:03:21.592834
# Epoch 131 starting...
# Epoch 131 completed after 3:04:45.099798
# Epoch 132 starting...
# Epoch 132 completed after 3:06:09.580739
# Epoch 133 starting...
# Epoch 133 completed after 3:07:33.134006
# Epoch 134 starting...
# Epoch 134 completed after 3:08:57.856341
# Epoch 135 starting...
# Epoch 135 completed after 3:10:21.498749
# Epoch 136 starting...
# Epoch 136 completed after 3:11:45.216965
# Epoch 137 starting...
# Epoch 137 completed after 3:13:08.982053
# Epoch 138 starting...
# Epoch 138 completed after 3:14:32.679022
# Epoch 139 starting...
# Epoch 139 completed after 3:15:56.722806
# Epoch 140 starting...
# Epoch 140 completed after 3:17:21.586066
# Epoch 141 starting...
# Epoch 141 completed after 3:18:44.343650
# Epoch 142 starting...
# Epoch 142 completed after 3:20:07.307771
# Epoch 143 starting...
# Epoch 143 completed after 3:21:30.875487
# Epoch 144 starting...
# Epoch 144 completed after 3:22:54.048025
# Epoch 145 starting...
# Epoch 145 completed after 3:24:16.999610
# Epoch 146 starting...
# Epoch 146 completed after 3:25:39.962670
# Epoch 147 starting...
# Epoch 147 completed after 3:27:02.491530
# Epoch 148 starting...
# Epoch 148 completed after 3:28:25.914980
# Epoch 149 starting...
# Epoch 149 completed after 3:29:48.551812
# Epoch 150 starting...
# Epoch 150 completed after 3:31:11.274074
# Epoch 151 starting...
# Epoch 151 completed after 3:32:33.529033
# Epoch 152 starting...
# Epoch 152 completed after 3:33:55.943880
# Epoch 153 starting...
# Epoch 153 completed after 3:35:18.312955
# Epoch 154 starting...
# Epoch 154 completed after 3:36:40.810047
# Epoch 155 starting...
# Epoch 155 completed after 3:38:03.385774
# Epoch 156 starting...
# Epoch 156 completed after 3:39:25.985156
# Epoch 157 starting...
# Epoch 157 completed after 3:40:49.295557
# Epoch 158 starting...
# Epoch 158 completed after 3:42:12.728998
# Epoch 159 starting...
# Epoch 159 completed after 3:43:36.542032
# Epoch 160 starting...
# Epoch 160 completed after 3:44:59.629988
# Epoch 161 starting...
# Epoch 161 completed after 3:46:22.093749
# Epoch 162 starting...
# Epoch 162 completed after 3:47:44.500385
# Epoch 163 starting...
# Epoch 163 completed after 3:49:07.279356
# Epoch 164 starting...
# Epoch 164 completed after 3:50:31.150889
# Epoch 165 starting...
# Epoch 165 completed after 3:51:53.757503
# Epoch 166 starting...
# Epoch 166 completed after 3:53:16.744756
# Epoch 167 starting...
# Epoch 167 completed after 3:54:39.434138
# Epoch 168 starting...
# Epoch 168 completed after 3:56:02.052845
# Epoch 169 starting...
# Epoch 169 completed after 3:57:25.374533
# Epoch 170 starting...
# Epoch 170 completed after 3:58:48.434854
# Epoch 171 starting...
# Epoch 171 completed after 4:00:12.155729
# Epoch 172 starting...
# Epoch 172 completed after 4:01:36.365430
# Epoch 173 starting...
# Epoch 173 completed after 4:03:00.045336
# Epoch 174 starting...
# Epoch 174 completed after 4:04:22.965991
# Epoch 175 starting...
# Epoch 175 completed after 4:05:46.234236
# Epoch 176 starting...
# Epoch 176 completed after 4:07:09.370895
# Epoch 177 starting...
# Epoch 177 completed after 4:08:33.149508
# Epoch 178 starting...
# Epoch 178 completed after 4:09:56.526288
# Epoch 179 starting...
# Epoch 179 completed after 4:11:20.121436
# Epoch 180 starting...
# Epoch 180 completed after 4:12:43.640289
# Epoch 181 starting...
# Epoch 181 completed after 4:14:07.918343
# Epoch 182 starting...
# Epoch 182 completed after 4:15:31.885311
# Epoch 183 starting...
# Epoch 183 completed after 4:16:55.426000
# Epoch 184 starting...
# Epoch 184 completed after 4:18:19.368698
# Epoch 185 starting...
# Epoch 185 completed after 4:19:42.910823
# Epoch 186 starting...
# Epoch 186 completed after 4:21:06.903553
# Epoch 187 starting...
# Epoch 187 completed after 4:22:31.363378
# Epoch 188 starting...
# Epoch 188 completed after 4:23:54.340518
# Epoch 189 starting...
# Epoch 189 completed after 4:25:19.241040
# Epoch 190 starting...
# Epoch 190 completed after 4:26:43.331106
# Epoch 191 starting...
# Epoch 191 completed after 4:28:07.302145
# Epoch 192 starting...
# Epoch 192 completed after 4:29:30.478706
# Epoch 193 starting...
# Epoch 193 completed after 4:30:54.421948
# Epoch 194 starting...
# Epoch 194 completed after 4:32:18.705994
# Epoch 195 starting...
# Epoch 195 completed after 4:33:44.159253
# Epoch 196 starting...
# Epoch 196 completed after 4:35:07.491840
# Epoch 197 starting...
# Epoch 197 completed after 4:36:33.170257
# Epoch 198 starting...
# Epoch 198 completed after 4:37:57.184537
# Epoch 199 starting...
# Epoch 199 completed after 4:39:20.474583
# Epoch 200 starting...
# Epoch 200 completed after 4:40:44.599452
# Epoch 201 starting...
# Epoch 201 completed after 4:42:08.035255
# Epoch 202 starting...
# Epoch 202 completed after 4:43:31.494669
# Epoch 203 starting...
# Epoch 203 completed after 4:44:54.877926
# Epoch 204 starting...
# Epoch 204 completed after 4:46:21.006756
# Epoch 205 starting...
# Epoch 205 completed after 4:47:45.107089
# Epoch 206 starting...
# Epoch 206 completed after 4:49:08.656442
# Epoch 207 starting...
# Epoch 207 completed after 4:50:31.847568
# Epoch 208 starting...
# Epoch 208 completed after 4:51:55.018327
# Epoch 209 starting...
# Epoch 209 completed after 4:53:18.490801
# Epoch 210 starting...
# Epoch 210 completed after 4:54:41.565253
# Epoch 211 starting...
# Epoch 211 completed after 4:56:04.868683
# Epoch 212 starting...
# Epoch 212 completed after 4:57:28.612341
# Epoch 213 starting...
# Epoch 213 completed after 4:58:51.952795
# Epoch 214 starting...
# Epoch 214 completed after 5:00:15.711084
# Epoch 215 starting...
# Epoch 215 completed after 5:01:40.269571
# Epoch 216 starting...
# Epoch 216 completed after 5:03:04.878414
# Epoch 217 starting...
# Epoch 217 completed after 5:04:30.779916
# Epoch 218 starting...
# Epoch 218 completed after 5:05:55.636595
# Epoch 219 starting...
# Epoch 219 completed after 5:07:19.012767
# Epoch 220 starting...
# Epoch 220 completed after 5:08:42.121014
# Epoch 221 starting...
# Epoch 221 completed after 5:10:05.482795
# Epoch 222 starting...
# Epoch 222 completed after 5:11:28.619330
# Epoch 223 starting...
# Epoch 223 completed after 5:12:51.602353
# Epoch 224 starting...
# Epoch 224 completed after 5:14:14.853015
# Epoch 225 starting...
# Epoch 225 completed after 5:15:38.153540
# Epoch 226 starting...
# Epoch 226 completed after 5:17:01.485970
# Epoch 227 starting...
# Epoch 227 completed after 5:18:25.313285
# Epoch 228 starting...
# Epoch 228 completed after 5:19:49.606456
# Epoch 229 starting...
# Epoch 229 completed after 5:21:13.956782
# Epoch 230 starting...
# Epoch 230 completed after 5:22:37.832798
# Epoch 231 starting...
# Epoch 231 completed after 5:24:02.962384
# Epoch 232 starting...
# Epoch 232 completed after 5:25:28.165246
# Epoch 233 starting...
# Epoch 233 completed after 5:26:52.711067
# Epoch 234 starting...
# Epoch 234 completed after 5:28:16.470025
# Epoch 235 starting...
# Epoch 235 completed after 5:29:40.032299
# Epoch 236 starting...
# Epoch 236 completed after 5:31:03.868214
# Epoch 237 starting...
# Epoch 237 completed after 5:32:27.168825
# Epoch 238 starting...
# Epoch 238 completed after 5:33:50.787573
# Epoch 239 starting...
# Epoch 239 completed after 5:35:14.755422
# Epoch 240 starting...
# Epoch 240 completed after 5:36:39.131983
# Epoch 241 starting...
# Epoch 241 completed after 5:38:04.328707
# Epoch 242 starting...
# Epoch 242 completed after 5:39:29.782598
# Epoch 243 starting...
# Epoch 243 completed after 5:40:54.812204
# Epoch 244 starting...
# Epoch 244 completed after 5:42:19.798439
# Epoch 245 starting...
# Epoch 245 completed after 5:43:44.461161
# Epoch 246 starting...
# Epoch 246 completed after 5:45:08.390638
# Epoch 247 starting...
# Epoch 247 completed after 5:46:31.664230
# Epoch 248 starting...
# Epoch 248 completed after 5:47:55.180413
# Epoch 249 starting...
# Epoch 249 completed after 5:49:18.403814
# Epoch 250 starting...
# Epoch 250 completed after 5:50:41.779044
# Epoch 251 starting...
# Epoch 251 completed after 5:52:05.318348
# Epoch 252 starting...
# Epoch 252 completed after 5:53:28.526136
# Epoch 253 starting...
# Epoch 253 completed after 5:54:52.104048
# Epoch 254 starting...
# Epoch 254 completed after 5:56:15.411763
# Epoch 255 starting...
# Epoch 255 completed after 5:57:39.655770
# Epoch 256 starting...
# Epoch 256 completed after 5:59:03.853585
# Epoch 257 starting...
# Epoch 257 completed after 6:00:28.022359
# Epoch 258 starting...
# Epoch 258 completed after 6:01:53.017773
# Epoch 259 starting...
# Epoch 259 completed after 6:03:17.366820
# Epoch 260 starting...
# Epoch 260 completed after 6:04:41.183310
# Epoch 261 starting...
# Epoch 261 completed after 6:06:05.638235
# Epoch 262 starting...
# Epoch 262 completed after 6:07:30.737983
# Epoch 263 starting...
# Epoch 263 completed after 6:08:54.824396
# Epoch 264 starting...
# Epoch 264 completed after 6:10:18.722280
# Epoch 265 starting...
# Epoch 265 completed after 6:11:42.133154
# Epoch 266 starting...
# Epoch 266 completed after 6:13:06.185672
# Epoch 267 starting...
# Epoch 267 completed after 6:14:30.401264
# Epoch 268 starting...
# Epoch 268 completed after 6:15:54.663636
# Epoch 269 starting...
# Epoch 269 completed after 6:17:18.581305
# Epoch 270 starting...
# Epoch 270 completed after 6:18:42.377627
# Epoch 271 starting...
# Epoch 271 completed after 6:20:06.236805
# Epoch 272 starting...
# Epoch 272 completed after 6:21:29.229917
# Epoch 273 starting...
# Epoch 273 completed after 6:22:52.161232
# Epoch 274 starting...
# Epoch 274 completed after 6:24:15.290965
# Epoch 275 starting...
# Epoch 275 completed after 6:25:38.630316
# Epoch 276 starting...
# Epoch 276 completed after 6:27:02.157918
# Epoch 277 starting...
# Epoch 277 completed after 6:28:26.225969
# Epoch 278 starting...
# Epoch 278 completed after 6:29:49.392637
# Epoch 279 starting...
# Epoch 279 completed after 6:31:12.741566
# Epoch 280 starting...
# Epoch 280 completed after 6:32:35.864909
# Epoch 281 starting...
# Epoch 281 completed after 6:33:59.042652
# Epoch 282 starting...
# Epoch 282 completed after 6:35:22.428546
# Epoch 283 starting...
# Epoch 283 completed after 6:36:45.564986
# Epoch 284 starting...
# Epoch 284 completed after 6:38:09.861190
# Epoch 285 starting...
# Epoch 285 completed after 6:39:33.452466
# Epoch 286 starting...
# Epoch 286 completed after 6:40:57.730542
# Epoch 287 starting...
# Epoch 287 completed after 6:42:23.977288
# Epoch 288 starting...
# Epoch 288 completed after 6:43:49.684501
# Epoch 289 starting...
# Epoch 289 completed after 6:45:15.273936
# Epoch 290 starting...
# Epoch 290 completed after 6:46:41.767472
# Epoch 291 starting...
# Epoch 291 completed after 6:48:09.112967
# Epoch 292 starting...
# Epoch 292 completed after 6:49:36.325811
# Epoch 293 starting...
# Epoch 293 completed after 6:51:01.467983
# Epoch 294 starting...
# Epoch 294 completed after 6:52:28.772411
# Epoch 295 starting...
# Epoch 295 completed after 6:53:56.397967
# Epoch 296 starting...
# Epoch 296 completed after 6:55:23.447294
# Epoch 297 starting...
# Epoch 297 completed after 6:56:49.801551
# Epoch 298 starting...
# Epoch 298 completed after 6:58:16.577473
# Epoch 299 starting...
# Epoch 299 completed after 6:59:40.828877
# Epoch 300 starting...
# Epoch 300 completed after 7:01:04.859546
# Epoch 301 starting...
# Epoch 301 completed after 7:02:29.208039
# Epoch 302 starting...
# Epoch 302 completed after 7:03:53.638993
# Epoch 303 starting...
# Epoch 303 completed after 7:05:20.399410
# Epoch 304 starting...
# Epoch 304 completed after 7:06:45.140522
# Epoch 305 starting...
# Epoch 305 completed after 7:08:10.117567
# Epoch 306 starting...
# Epoch 306 completed after 7:09:35.922143
# Epoch 307 starting...
# Epoch 307 completed after 7:11:00.895049
# Epoch 308 starting...
# Epoch 308 completed after 7:12:26.766018
# Epoch 309 starting...
# Epoch 309 completed after 7:13:54.317667
# Epoch 310 starting...
# Epoch 310 completed after 7:15:19.054173
# Epoch 311 starting...
# Epoch 311 completed after 7:16:44.599889
# Epoch 312 starting...
# Epoch 312 completed after 7:18:08.878869
# Epoch 313 starting...
# Epoch 313 completed after 7:19:33.136662
# Epoch 314 starting...
# Epoch 314 completed after 7:20:57.733053
# Epoch 315 starting...
# Epoch 315 completed after 7:22:22.799247
# Epoch 316 starting...
# Epoch 316 completed after 7:23:49.393121
# Epoch 317 starting...
# Epoch 317 completed after 7:25:14.876842
# Epoch 318 starting...
# Epoch 318 completed after 7:26:41.135295
# Epoch 319 starting...
# Epoch 319 completed after 7:28:05.283940
# Epoch 320 starting...
# Epoch 320 completed after 7:29:28.899667
# Epoch 321 starting...
# Epoch 321 completed after 7:30:52.043702
# Epoch 322 starting...
# Epoch 322 completed after 7:32:15.552776
# Epoch 323 starting...
# Epoch 323 completed after 7:33:39.026713
# Epoch 324 starting...
# Epoch 324 completed after 7:35:02.447258
# Epoch 325 starting...
# Epoch 325 completed after 7:36:25.860466
# Epoch 326 starting...
# Epoch 326 completed after 7:37:49.930268
# Epoch 327 starting...
# Epoch 327 completed after 7:39:13.204149
# Epoch 328 starting...
# Epoch 328 completed after 7:40:36.430639
# Epoch 329 starting...
# Epoch 329 completed after 7:41:59.696799
# Epoch 330 starting...
# Epoch 330 completed after 7:43:22.972111
# Epoch 331 starting...
# Epoch 331 completed after 7:44:46.288936
# Epoch 332 starting...
# Epoch 332 completed after 7:46:09.489657
# Epoch 333 starting...
# Epoch 333 completed after 7:47:32.476650
# Epoch 334 starting...
# Epoch 334 completed after 7:48:55.673808
# Epoch 335 starting...
# Epoch 335 completed after 7:50:19.058693
# Epoch 336 starting...
# Epoch 336 completed after 7:51:42.282220
# Epoch 337 starting...
# Epoch 337 completed after 7:53:06.622614
# Epoch 338 starting...
# Epoch 338 completed after 7:54:33.569695
# Epoch 339 starting...
# Epoch 339 completed after 7:55:57.874530
# Epoch 340 starting...
# Epoch 340 completed after 7:57:21.119057
# Epoch 341 starting...
# Epoch 341 completed after 7:58:44.211910
# Epoch 342 starting...
# Epoch 342 completed after 8:00:07.264597
# Epoch 343 starting...
# Epoch 343 completed after 8:01:31.008424
# Epoch 344 starting...
# Epoch 344 completed after 8:02:54.690205
# Epoch 345 starting...
# Epoch 345 completed after 8:04:18.179174
# Epoch 346 starting...
# Epoch 346 completed after 8:05:41.296231
# Epoch 347 starting...
# Epoch 347 completed after 8:07:04.981261
# Epoch 348 starting...
# Epoch 348 completed after 8:08:28.635101
# Epoch 349 starting...
# Epoch 349 completed after 8:09:51.931833
# Epoch 350 starting...
# Epoch 350 completed after 8:11:15.664896
# Epoch 351 starting...
# Epoch 351 completed after 8:12:38.999090
# Epoch 352 starting...
# Epoch 352 completed after 8:14:02.243940
# Epoch 353 starting...
# Epoch 353 completed after 8:15:25.456690
# Epoch 354 starting...
# Epoch 354 completed after 8:16:48.800536
# Epoch 355 starting...
# Epoch 355 completed after 8:18:12.388850
# Epoch 356 starting...
# Epoch 356 completed after 8:19:35.878238
# Epoch 357 starting...
# Epoch 357 completed after 8:21:00.610684
# Epoch 358 starting...
# Epoch 358 completed after 8:22:27.265587
# Epoch 359 starting...
# Epoch 359 completed after 8:23:54.355640
# Epoch 360 starting...
# Epoch 360 completed after 8:25:19.451927
# Epoch 361 starting...
# Epoch 361 completed after 8:26:44.512315
# Epoch 362 starting...
# Epoch 362 completed after 8:28:09.634099
# Epoch 363 starting...
# Epoch 363 completed after 8:29:33.260317
# Epoch 364 starting...
# Epoch 364 completed after 8:30:57.802876
# Epoch 365 starting...
# Epoch 365 completed after 8:32:23.198445
# Epoch 366 starting...
# Epoch 366 completed after 8:33:46.698288
# Epoch 367 starting...
# Epoch 367 completed after 8:35:11.092719
# Epoch 368 starting...
# Epoch 368 completed after 8:36:37.817963
# Epoch 369 starting...
# Epoch 369 completed after 8:38:05.489024
# Epoch 370 starting...
# Epoch 370 completed after 8:39:33.091948
# Epoch 371 starting...
# Epoch 371 completed after 8:41:00.118727
# Epoch 372 starting...
# Epoch 372 completed after 8:42:25.002241
# Epoch 373 starting...
# Epoch 373 completed after 8:43:50.652991
# Epoch 374 starting...
# Epoch 374 completed after 8:45:16.661422
# Epoch 375 starting...
# Epoch 375 completed after 8:46:43.667351
# Epoch 376 starting...
# Epoch 376 completed after 8:48:09.857105
# Epoch 377 starting...
# Epoch 377 completed after 8:49:35.142184
# Epoch 378 starting...
# Epoch 378 completed after 8:51:02.205087
# Epoch 379 starting...
# Epoch 379 completed after 8:52:28.776377
# Epoch 380 starting...
# Epoch 380 completed after 8:53:53.035246
# Epoch 381 starting...
# Epoch 381 completed after 8:55:16.731239
# Epoch 382 starting...
# Epoch 382 completed after 8:56:40.472078
# Epoch 383 starting...
# Epoch 383 completed after 8:58:06.004649
# Epoch 384 starting...
# Epoch 384 completed after 8:59:31.401248
# Epoch 385 starting...
# Epoch 385 completed after 9:00:55.719361
# Epoch 386 starting...
# Epoch 386 completed after 9:02:19.482326
# Epoch 387 starting...
# Epoch 387 completed after 9:03:42.716457
# Epoch 388 starting...
# Epoch 388 completed after 9:05:06.724659
# Epoch 389 starting...
# Epoch 389 completed after 9:06:30.227352
# Epoch 390 starting...
# Epoch 390 completed after 9:07:53.905276
# Epoch 391 starting...
# Epoch 391 completed after 9:09:18.220484
# Epoch 392 starting...
# Epoch 392 completed after 9:10:42.015764
# Epoch 393 starting...
# Epoch 393 completed after 9:12:05.916152
# Epoch 394 starting...
# Epoch 394 completed after 9:13:29.182332
# Epoch 395 starting...
# Epoch 395 completed after 9:14:52.880733
# Epoch 396 starting...
# Epoch 396 completed after 9:16:16.868879
# Epoch 397 starting...
# Epoch 397 completed after 9:17:41.828907
# Epoch 398 starting...
# Epoch 398 completed after 9:19:07.450578
# Epoch 399 starting...
# Epoch 399 completed after 9:20:32.676837
# Epoch 400 starting...
# Epoch 400 completed after 9:21:58.015047
# Epoch 401 starting...
# Epoch 401 completed after 9:23:22.962342
# Epoch 402 starting...
# Epoch 402 completed after 9:24:47.079202
# Epoch 403 starting...
# Epoch 403 completed after 9:26:10.155525
# Epoch 404 starting...
# Epoch 404 completed after 9:27:33.379308
# Epoch 405 starting...
# Epoch 405 completed after 9:28:58.874709
# Epoch 406 starting...
# Epoch 406 completed after 9:30:24.400392
# Epoch 407 starting...
# Epoch 407 completed after 9:31:51.121507
# Epoch 408 starting...
# Epoch 408 completed after 9:33:15.389015
# Epoch 409 starting...
# Epoch 409 completed after 9:34:41.729550
# Epoch 410 starting...
# Epoch 410 completed after 9:36:09.541528
# Epoch 411 starting...
# Epoch 411 completed after 9:37:35.950388
# Epoch 412 starting...
# Epoch 412 completed after 9:39:02.424095
# Epoch 413 starting...
# Epoch 413 completed after 9:40:28.892857
# Epoch 414 starting...
# Epoch 414 completed after 9:41:56.361295
# Epoch 415 starting...
# Epoch 415 completed after 9:43:22.664724
# Epoch 416 starting...
# Epoch 416 completed after 9:44:49.074485
# Epoch 417 starting...
# Epoch 417 completed after 9:46:14.675085
# Epoch 418 starting...
# Epoch 418 completed after 9:47:39.818750
# Epoch 419 starting...
# Epoch 419 completed after 9:49:05.105099
# Epoch 420 starting...
# Epoch 420 completed after 9:50:29.423952
# Epoch 421 starting...
# Epoch 421 completed after 9:51:54.941368
# Epoch 422 starting...
# Epoch 422 completed after 9:53:21.482456
# Epoch 423 starting...
# Epoch 423 completed after 9:54:45.019289
# Epoch 424 starting...
# Epoch 424 completed after 9:56:09.326683
# Epoch 425 starting...
# Epoch 425 completed after 9:57:33.517979
# Epoch 426 starting...
# Epoch 426 completed after 9:58:57.264741
# Epoch 427 starting...
# Epoch 427 completed after 10:00:20.660388
# Epoch 428 starting...
# Epoch 428 completed after 10:01:46.919586
# Epoch 429 starting...
# Epoch 429 completed after 10:03:11.138315
# Epoch 430 starting...
# Epoch 430 completed after 10:04:36.007720
# Epoch 431 starting...
# Epoch 431 completed after 10:05:59.261150
# Epoch 432 starting...
# Epoch 432 completed after 10:07:22.445192
# Epoch 433 starting...
# Epoch 433 completed after 10:08:46.337689
# Epoch 434 starting...
# Epoch 434 completed after 10:10:09.408229
# Epoch 435 starting...
# Epoch 435 completed after 10:11:32.925565
# Epoch 436 starting...
# Epoch 436 completed after 10:12:55.967718
# Epoch 437 starting...
# Epoch 437 completed after 10:14:19.557313
# Epoch 438 starting...
# Epoch 438 completed after 10:15:42.708258
# Epoch 439 starting...
# Epoch 439 completed after 10:17:05.609028
# Epoch 440 starting...
# Epoch 440 completed after 10:18:29.012873
# Epoch 441 starting...
# Epoch 441 completed after 10:19:53.682849
# Epoch 442 starting...
# Epoch 442 completed after 10:21:17.636696
# Epoch 443 starting...
# Epoch 443 completed after 10:22:40.617380
# Epoch 444 starting...
# Epoch 444 completed after 10:24:04.218952
# Epoch 445 starting...
# Epoch 445 completed after 10:25:30.629218
# Epoch 446 starting...
# Epoch 446 completed after 10:26:56.783454
# Epoch 447 starting...
# Epoch 447 completed after 10:28:21.710650
# Epoch 448 starting...
# Epoch 448 completed after 10:29:45.816390
# Epoch 449 starting...
# Epoch 449 completed after 10:31:09.946999
# Epoch 450 starting...
# Epoch 450 completed after 10:32:36.388661
# Epoch 451 starting...
# Epoch 451 completed after 10:34:03.997348
# Epoch 452 starting...
# Epoch 452 completed after 10:35:31.229993
# Epoch 453 starting...
# Epoch 453 completed after 10:36:58.434316
# Epoch 454 starting...
# Epoch 454 completed after 10:38:26.169716
# Epoch 455 starting...
# Epoch 455 completed after 10:39:54.126122
# Epoch 456 starting...
# Epoch 456 completed after 10:41:18.059609
# Epoch 457 starting...
# Epoch 457 completed after 10:42:41.396994
# Epoch 458 starting...
# Epoch 458 completed after 10:44:05.055073
# Epoch 459 starting...
# Epoch 459 completed after 10:45:29.540578
# Epoch 460 starting...
# Epoch 460 completed after 10:46:53.328172
# Epoch 461 starting...
# Epoch 461 completed after 10:48:16.809685
# Epoch 462 starting...
# Epoch 462 completed after 10:49:39.948908
# Epoch 463 starting...
# Epoch 463 completed after 10:51:03.419099
# Epoch 464 starting...
# Epoch 464 completed after 10:52:26.927982
# Epoch 465 starting...
# Epoch 465 completed after 10:53:50.582501
# Epoch 466 starting...
# Epoch 466 completed after 10:55:13.864395
# Epoch 467 starting...
# Epoch 467 completed after 10:56:37.577635
# Epoch 468 starting...
# Epoch 468 completed after 10:58:01.776940
# Epoch 469 starting...
# Epoch 469 completed after 10:59:25.705521
# Epoch 470 starting...
# Epoch 470 completed after 11:00:49.681977
# Epoch 471 starting...
# Epoch 471 completed after 11:02:15.787828
# Epoch 472 starting...
# Epoch 472 completed after 11:03:40.851388
# Epoch 473 starting...
# Epoch 473 completed after 11:05:05.242913
# Epoch 474 starting...
# Epoch 474 completed after 11:06:30.699720
# Epoch 475 starting...
# Epoch 475 completed after 11:07:57.663530
# Epoch 476 starting...
# Epoch 476 completed after 11:09:24.105086
# Epoch 477 starting...
# Epoch 477 completed after 11:10:51.406962
# Epoch 478 starting...
# Epoch 478 completed after 11:12:18.818650
# Epoch 479 starting...
# Epoch 479 completed after 11:13:46.210265
# Epoch 480 starting...
# Epoch 480 completed after 11:15:12.105405
# Epoch 481 starting...
# Epoch 481 completed after 11:16:38.910355
# Epoch 482 starting...
# Epoch 482 completed after 11:18:04.493103
# Epoch 483 starting...
# Epoch 483 completed after 11:19:31.297187
# Epoch 484 starting...
# Epoch 484 completed after 11:20:57.590578
# Epoch 485 starting...
# Epoch 485 completed after 11:22:23.541671
# Epoch 486 starting...
# Epoch 486 completed after 11:23:50.332740
# Epoch 487 starting...
# Epoch 487 completed after 11:25:17.528170
# Epoch 488 starting...
# Epoch 488 completed after 11:26:44.860250
# Epoch 489 starting...
# Epoch 489 completed after 11:28:12.273822
# Epoch 490 starting...
# Epoch 490 completed after 11:29:39.729126
# Epoch 491 starting...
# Epoch 491 completed after 11:31:07.072616
# Epoch 492 starting...
# Epoch 492 completed after 11:32:34.467532
# Epoch 493 starting...
# Epoch 493 completed after 11:34:01.985729
# Epoch 494 starting...
# Epoch 494 completed after 11:35:29.282825
# Epoch 495 starting...
# Epoch 495 completed after 11:36:55.744210
# Epoch 496 starting...
# Epoch 496 completed after 11:38:23.393298
# Epoch 497 starting...
# Epoch 497 completed after 11:39:49.573818
# Epoch 498 starting...
# Epoch 498 completed after 11:41:14.708610
# Epoch 499 starting...
# Epoch 499 completed after 11:42:38.298074
# Epoch 500 starting...
# Epoch 500 completed after 11:44:02.179142
# Epoch 501 starting...
# Epoch 501 completed after 11:45:27.372404
# Epoch 502 starting...
# Epoch 502 completed after 11:46:53.965920
# Epoch 503 starting...
# Epoch 503 completed after 11:48:19.338460
# Epoch 504 starting...
# Epoch 504 completed after 11:49:43.474783
# Epoch 505 starting...
# Epoch 505 completed after 11:51:06.945904
# Epoch 506 starting...
# Epoch 506 completed after 11:52:30.182086
# Epoch 507 starting...
# Epoch 507 completed after 11:53:56.467152
# Epoch 508 starting...
# Epoch 508 completed after 11:55:23.709948
# Epoch 509 starting...
# Epoch 509 completed after 11:56:51.086855
# Epoch 510 starting...
# Epoch 510 completed after 11:58:17.957937
# Epoch 511 starting...
# Epoch 511 completed after 11:59:44.173911
# Epoch 512 starting...
# Epoch 512 completed after 12:01:07.866315
# Epoch 513 starting...
# Epoch 513 completed after 12:02:31.623884
# Epoch 514 starting...
# Epoch 514 completed after 12:03:55.514515
# Epoch 515 starting...
# Epoch 515 completed after 12:05:21.845968
# Epoch 516 starting...
# Epoch 516 completed after 12:06:46.399981
# Epoch 517 starting...
# Epoch 517 completed after 12:08:11.850018
# Saved population for epoch 517 with precision 0.9144
# Epoch 518 starting...
# Epoch 518 completed after 12:09:35.112041
# Epoch 519 starting...
# Epoch 519 completed after 12:10:58.486223
# Epoch 520 starting...
# Epoch 520 completed after 12:12:21.876046
# Epoch 521 starting...
# Epoch 521 completed after 12:13:45.195950
# Epoch 522 starting...
# Epoch 522 completed after 12:15:09.099056
# Epoch 523 starting...
# Epoch 523 completed after 12:16:32.756379
# Epoch 524 starting...
# Epoch 524 completed after 12:17:56.135544
# Epoch 525 starting...
# Epoch 525 completed after 12:19:20.423994
# Epoch 526 starting...
# Epoch 526 completed after 12:20:44.999497
# Epoch 527 starting...
# Epoch 527 completed after 12:22:08.480009
# Epoch 528 starting...
# Epoch 528 completed after 12:23:33.464089
# Epoch 529 starting...
# Epoch 529 completed after 12:24:57.909239
# Epoch 530 starting...
# Epoch 530 completed after 12:26:21.452414
# Epoch 531 starting...
# Epoch 531 completed after 12:27:45.806439
# Epoch 532 starting...
# Epoch 532 completed after 12:29:09.490273
# Epoch 533 starting...
# Epoch 533 completed after 12:30:33.201374
# Epoch 534 starting...
# Epoch 534 completed after 12:31:57.383402
# Epoch 535 starting...
# Epoch 535 completed after 12:33:20.985505
# Epoch 536 starting...
# Epoch 536 completed after 12:34:45.015674
# Epoch 537 starting...
# Epoch 537 completed after 12:36:08.722509
# Epoch 538 starting...
# Epoch 538 completed after 12:37:32.159638
# Epoch 539 starting...
# Epoch 539 completed after 12:38:56.184682
# Epoch 540 starting...
# Epoch 540 completed after 12:40:21.647204
# Epoch 541 starting...
# Epoch 541 completed after 12:41:45.416418
# Epoch 542 starting...
# Epoch 542 completed after 12:43:12.411564
# Epoch 543 starting...
# Epoch 543 completed after 12:44:38.573680
# Epoch 544 starting...
# Epoch 544 completed after 12:46:03.005947
# Epoch 545 starting...
# Epoch 545 completed after 12:47:27.594366
# Epoch 546 starting...
# Epoch 546 completed after 12:48:51.912199
# Epoch 547 starting...
# Epoch 547 completed after 12:50:16.475797
# Epoch 548 starting...
# Epoch 548 completed after 12:51:41.040128
# Epoch 549 starting...
# Epoch 549 completed after 12:53:04.934374
# Epoch 550 starting...
# Epoch 550 completed after 12:54:28.661320
# Epoch 551 starting...
# Epoch 551 completed after 12:55:52.136617
# Epoch 552 starting...
# Epoch 552 completed after 12:57:15.813821
# Epoch 553 starting...
# Epoch 553 completed after 12:58:39.194076
# Epoch 554 starting...
# Epoch 554 completed after 13:00:02.691776
# Epoch 555 starting...
# Epoch 555 completed after 13:01:25.991688
# Epoch 556 starting...
# Epoch 556 completed after 13:02:49.117735
# Epoch 557 starting...
# Epoch 557 completed after 13:04:12.926377
# Epoch 558 starting...
# Epoch 558 completed after 13:05:37.019035
# Epoch 559 starting...
# Epoch 559 completed after 13:07:01.079162
# Epoch 560 starting...
# Epoch 560 completed after 13:08:24.333208
# Epoch 561 starting...
# Epoch 561 completed after 13:09:48.031204
# Epoch 562 starting...
# Epoch 562 completed after 13:11:11.673918
# Epoch 563 starting...
# Epoch 563 completed after 13:12:35.266593
# Epoch 564 starting...
# Epoch 564 completed after 13:13:59.127918
# Epoch 565 starting...
# Epoch 565 completed after 13:15:23.123257
# Epoch 566 starting...
# Epoch 566 completed after 13:16:46.936295
# Epoch 567 starting...
# Epoch 567 completed after 13:18:12.491004
# Epoch 568 starting...
# Epoch 568 completed after 13:19:37.948742
# Epoch 569 starting...
# Epoch 569 completed after 13:21:03.748140
# Epoch 570 starting...
# Epoch 570 completed after 13:22:27.922857
# Epoch 571 starting...
# Epoch 571 completed after 13:23:52.402732
# Epoch 572 starting...
# Epoch 572 completed after 13:25:16.677468
# Epoch 573 starting...
# Epoch 573 completed after 13:26:42.194238
# Epoch 574 starting...
# Epoch 574 completed after 13:28:08.426085
# Epoch 575 starting...
# Epoch 575 completed after 13:29:32.548869
# Epoch 576 starting...
# Epoch 576 completed after 13:30:57.810024
# Epoch 577 starting...
# Epoch 577 completed after 13:32:23.020793
# Epoch 578 starting...
# Epoch 578 completed after 13:33:48.590764
# Epoch 579 starting...
# Epoch 579 completed after 13:35:11.785812
# Epoch 580 starting...
# Epoch 580 completed after 13:36:35.459238
# Epoch 581 starting...
# Epoch 581 completed after 13:38:00.487422
# Epoch 582 starting...
# Epoch 582 completed after 13:39:26.381484
# Epoch 583 starting...
# Epoch 583 completed after 13:40:50.595969
# Epoch 584 starting...
# Epoch 584 completed after 13:42:17.670269
# Epoch 585 starting...
# Epoch 585 completed after 13:43:44.121939
# Epoch 586 starting...
# Epoch 586 completed after 13:45:08.447306
# Epoch 587 starting...
# Epoch 587 completed after 13:46:33.922731
# Epoch 588 starting...
# Epoch 588 completed after 13:47:58.870790
# Epoch 589 starting...
# Epoch 589 completed after 13:49:22.526556
# Epoch 590 starting...
# Epoch 590 completed after 13:50:46.079595
# Epoch 591 starting...
# Epoch 591 completed after 13:52:09.929970
# Epoch 592 starting...
# Epoch 592 completed after 13:53:34.143631
# Epoch 593 starting...
# Epoch 593 completed after 13:54:58.589401
# Epoch 594 starting...
# Epoch 594 completed after 13:56:24.049028
# Epoch 595 starting...
# Epoch 595 completed after 13:57:47.624111
# Epoch 596 starting...
# Epoch 596 completed after 13:59:13.697344
# Epoch 597 starting...
# Epoch 597 completed after 14:00:39.477870
# Epoch 598 starting...
# Epoch 598 completed after 14:02:03.607498
# Epoch 599 starting...
# Epoch 599 completed after 14:03:27.330218
# Epoch 600 starting...
# Epoch 600 completed after 14:04:52.154637
# Epoch 601 starting...
# Epoch 601 completed after 14:06:16.081932
# Epoch 602 starting...
# Epoch 602 completed after 14:07:39.554336
# Epoch 603 starting...
# Epoch 603 completed after 14:09:03.052623
# Epoch 604 starting...
# Epoch 604 completed after 14:10:26.587179
# Epoch 605 starting...
# Epoch 605 completed after 14:11:51.133381
# Epoch 606 starting...
# Epoch 606 completed after 14:13:16.813971
# Epoch 607 starting...
# Epoch 607 completed after 14:14:41.309842
# Epoch 608 starting...
# Epoch 608 completed after 14:16:06.071653
# Epoch 609 starting...
# Epoch 609 completed after 14:17:30.045503
# Epoch 610 starting...
# Epoch 610 completed after 14:18:53.985445
# Epoch 611 starting...
# Epoch 611 completed after 14:20:17.999307
# Epoch 612 starting...
# Epoch 612 completed after 14:21:43.404935
# Epoch 613 starting...
# Epoch 613 completed after 14:23:07.729560
# Epoch 614 starting...
# Epoch 614 completed after 14:24:33.914790
# Epoch 615 starting...
# Epoch 615 completed after 14:25:57.788630
# Epoch 616 starting...
# Epoch 616 completed after 14:27:22.182812
# Epoch 617 starting...
# Epoch 617 completed after 14:28:46.968567
# Epoch 618 starting...
# Epoch 618 completed after 14:30:11.217632
# Epoch 619 starting...
# Epoch 619 completed after 14:31:34.755554
# Epoch 620 starting...
# Epoch 620 completed after 14:32:59.423061
# Epoch 621 starting...
# Epoch 621 completed after 14:34:24.043138
# Epoch 622 starting...
# Epoch 622 completed after 14:35:49.466126
# Epoch 623 starting...
# Epoch 623 completed after 14:37:13.333839
# Epoch 624 starting...
# Epoch 624 completed after 14:38:37.197886
# Epoch 625 starting...
# Epoch 625 completed after 14:40:00.563079
# Epoch 626 starting...
# Epoch 626 completed after 14:41:24.346177
# Epoch 627 starting...
# Epoch 627 completed after 14:42:48.954339
# Epoch 628 starting...
# Epoch 628 completed after 14:44:12.714108
# Epoch 629 starting...
# Epoch 629 completed after 14:45:36.318965
# Epoch 630 starting...
# Epoch 630 completed after 14:47:00.307055
# Epoch 631 starting...
# Epoch 631 completed after 14:48:23.973244
# Epoch 632 starting...
# Epoch 632 completed after 14:49:47.631212
# Epoch 633 starting...
# Epoch 633 completed after 14:51:10.854031
# Epoch 634 starting...
# Epoch 634 completed after 14:52:34.293179
# Epoch 635 starting...
# Epoch 635 completed after 14:53:57.820328
# Epoch 636 starting...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 44
#      39     optimizer.mutation_strength = mutation_decay(
#      40         gen / generations, k=8, mu0=mutation_strength
#      41     )
#      42     optimizer.mutation_rate = mutation_decay(gen / generations, k=8, mu0=mutation_rate)
# ---> 44     (population, best_precision) = optimizer.run_generation()
#      45     # print(f"Epoch: {epoch} {gen+1}/{generations} - Best Precision: {best_precision:.4f}")
#      47 elapsed_time = time.time() - start_time
#
# Cell In[5], line 117, in EvolutionaryOptimizer.run_generation(self)
#     114 evaluated = self.evaluate()
#     115 best_precision = max(precision for _, precision in evaluated)
# --> 117 self.select_and_breed(evaluated)
#     119 return self.population, best_precision
#
# Cell In[5], line 101, in EvolutionaryOptimizer.select_and_breed(self, evaluated)
#      98     child = copy.deepcopy(parent)
#     100     # Mutate the child
# --> 101     child.mutate(self.mutation_rate, self.mutation_strength)
#     102     new_population.append(child)
#     104 # Add random new members
#
# Cell In[4], line 84, in SimpleNeuralNetwork.mutate(self, mutation_rate, mutation_strength)
#      82 with torch.no_grad():
#      83     for param in self.parameters():
# ---> 84         if torch.rand(1).item() < mutation_rate:
#      85             mutation = torch.randn_like(param) * mutation_strength
#      86             param.add_(mutation)
#
# KeyboardInterrupt:

# %%
# Generate submission files for all saved populations
for dirname, _, filenames in os.walk(folder):
    for filename in filenames:
        print(os.path.join(dirname, filename))

        population = load_population(os.path.join(dirname, filename))
        network = population[0]

        checkpoint = filename.split("_")[-1].split(".")[0]
        print(f"Generating submission for checkpoint {checkpoint}...")

        predictions = []
        for test in test_data:
            input_values = test['input']
            prediction = network.forward(input_values)
            # prediction = prediction.cpu()
            prediction = True if prediction[0] > .5 else False
            # print(f"Passenger ID: {test['id']}, Survived: {1 if prediction else 0}")
            predictions.append([test['id'], 1 if prediction else 0])

        # Save predictions to CSV
        with open(f"submission_{checkpoint}.csv", "w", newline="") as csvfile:
            fieldnames = ["PassengerId", "Survived"]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            writer.writeheader()
            for pid, survived in predictions:
                writer.writerow({"PassengerId": pid, "Survived": survived})



# population = load_population('networks/256/population_epoch_228.pkl')
# network = population[0]
# Out:
# networks/16_8_4_2/population_epoch_5.pkl
# Generating submission for checkpoint 5...
# networks/16_8_4_2/population_epoch_1.pkl
# Generating submission for checkpoint 1...
# networks/16_8_4_2/population_epoch_517.pkl
# Generating submission for checkpoint 517...
# networks/16_8_4_2/population_epoch_40.pkl
# Generating submission for checkpoint 40...
# networks/16_8_4_2/population_epoch_3.pkl
# Generating submission for checkpoint 3...
# networks/16_8_4_2/population_epoch_21.pkl
# Generating submission for checkpoint 21...

# %%
# Select network from the optimizer
network = optimizer.population[0]

# %%
predictions = []
for test in test_data:
    input_values = test['input']
    prediction = network.forward(input_values)
    # prediction = prediction.cpu()
    prediction = True if prediction[0] > .5 else False
    # print(f"Passenger ID: {test['id']}, Survived: {1 if prediction else 0}")
    predictions.append([test['id'], 1 if prediction else 0])

# Save predictions to CSV
with open("submission.csv", "w", newline="") as csvfile:
    fieldnames = ["PassengerId", "Survived"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for pid, survived in predictions:
        writer.writerow({"PassengerId": pid, "Survived": survived})

# %%
mutation_decay(1, mu0=0.25, k=8.0)
# Out:
# np.float64(8.386565697562796e-05)
